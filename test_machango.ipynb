# %%
machango = ['''

   +---+
   |   |
       |
       |
       |
       |
=========''', '''

   +---+
   |   |
   O   |
       |
       |
       |
=========''', '''


   +---+
   |   |
   O   |
   |   |
       |
       |
=========''', '''


   +---+
   |   |
   O   |
  /|   |
       |
       |
=========''', '''


   +---+
   |   |
   O   |
  /|\  |
       |
       |
=========''', '''


   +---+
   |   |
   O   |
  /|\  |
  /    |
       |
=========''', '''


   +---+
   |   |
   O   |
  /|\  |
  / \  |
       |
=========''']

# %%
lista_palabras = [ "casa", "marga", "elena", "silla", "belen", "pantalla"]
import random
palabra_oculta = random.choice(lista_palabras)
palabra_oculta_lista = list(palabra_oculta)
palabra_usuario = palabra_oculta_lista.copy()
print(palabra_oculta_lista)
vidas = 7
contador_machango = 0 
#contador_machango[0:6]
print(machango[contador_machango])
letra_escogida = input('Ecriba una letra').lower()
acierto =False

for letra in range(len(palabra_usuario)):
    palabra_usuario[letra] = '*'

# empezar el while 
while vidas > 1 and palabra_oculta_lista!= palabra_usuario and contador_machango <= 6:
    letra_escogida = input('Ecriba una letra').lower()
  
    if palabra_oculta.count(letra_escogida) > 0:

        for  i, valor in enumerate(palabra_oculta_lista): 
             if valor == letra_escogida: 
                  palabra_usuario[i] = letra_escogida
                  print(palabra_usuario)
             
    else: 
        vidas -= 1
        contador_machango += 1
        print(contador_machango)
        print(f'tu letra es {letra_escogida}, y no está')
        print(f"moooooc, has perdido una vida, te quedan {vidas} vidas")
        print(machango[contador_machango])

if vidas <=1:
    print(f"Has perdido, te quedan 0 vidas, la palabra era {palabra_oculta}")
    print(machango[-1])
# Out:
# ['c', 'a', 's', 'a']
#
#
#    +---+
#    |   |
#        |
#        |
#        |
#        |
# =========
# 1
# tu letra es b, y no está
# moooooc, has perdido una vida, te quedan 6 vidas
#
#
#    +---+
#    |   |
#    O   |
#        |
#        |
#        |
# =========
# 2
# tu letra es b, y no está
# moooooc, has perdido una vida, te quedan 5 vidas
#
#
#
#    +---+
#    |   |
#    O   |
#    |   |
#        |
#        |
# =========
# 3
# tu letra es b, y no está
# moooooc, has perdido una vida, te quedan 4 vidas
#
#
#
#    +---+
#    |   |
#    O   |
#   /|   |
#        |
#        |
# =========
# 4
# tu letra es b, y no está
# moooooc, has perdido una vida, te quedan 3 vidas
#
#
#
#    +---+
#    |   |
#    O   |
#   /|\  |
#        |
#        |
# =========
# 5
# tu letra es b, y no está
# moooooc, has perdido una vida, te quedan 2 vidas
#
#
#
#    +---+
#    |   |
#    O   |
#   /|\  |
#   /    |
#        |
# =========
# 6
# tu letra es b, y no está
# moooooc, has perdido una vida, te quedan 1 vidas
#
#
#
#    +---+
#    |   |
#    O   |
#   /|\  |
#   / \  |
#        |
# =========
# Has perdido, te quedan 0 vidas, la palabra era casa
#
#
#
#    +---+
#    |   |
#    O   |
#   /|\  |
#   / \  |
#        |
# =========

# %%
lista_palabras = [ "casa", "marga", "elena", "silla", "belen", "pantalla"]
import random
palabra_oculta = random.choice(lista_palabras)
palabra_oculta_lista = list(palabra_oculta)
palabra_usuario = palabra_oculta_lista.copy()
print(palabra_oculta_lista)
vidas = 7

contador_machango = 0 
letra_escogida = input('Ecriba una letra').lower()
acierto =False

for letra in range(len(palabra_usuario)):
    palabra_usuario[letra] = '*'

# empezar el while 
while vidas >= 1  and palabra_oculta_lista!= palabra_usuario:
    letra_escogida = input('Ecriba una letra').lower()
  
    #Si tengo la misma letra +dos veces: 
    if palabra_oculta.count(letra_escogida) > 0:

        for  i, valor in enumerate(palabra_oculta_lista): 
             if valor == letra_escogida: 
                  palabra_usuario[i] = letra_escogida
                  print(palabra_usuario)
             
    else: 
        vidas -= 1
        
        contador_indice_machango += 1
    
        print(f'tu letra es {letra_escogida}, y no está')
        print(f"moooooc, has perdido una vida, te quedan {vidas} vidas")
        print(machango[contador_machango])

if vidas == 0:
    print(f"Has perdido, te quedan 0 vidas, la palabra era {palabra_oculta}")
    print(machango[-1])
# Out:
# ['p', 'a', 'n', 't', 'a', 'l', 'l', 'a']
# ['p', '*', '*', '*', '*', '*', '*', '*']

# %%
import random

# %%
nombres = ["marga", "elena", "belen"]

scrum = random.choice(nombres)

print(scrum)
# Out:
# marga
